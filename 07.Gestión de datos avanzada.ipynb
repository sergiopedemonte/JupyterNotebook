# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:/Users/pauli/Downloads/Datos/base_datos_2008.csv", nrows = 100000)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
np.corrcoef(df["ArrDelay"],df["DepDelay"])
# muestra la correlación entre las columnas especificadas. El resultado es una matriz con valores nulos dado que el df
# hay datos faltantes, que deben ser imputados o eliminados antes de realizar el cálculo.
# Out:
# array([[nan, nan],
#        [nan, nan]])

# %%
df.dropna(inplace = True, subset=["ArrDelay","DepDelay"])
# Elimina valores faltantes de las columnas especificadas.

# %%
np.corrcoef(df["ArrDelay"],df["DepDelay"])
# ahora ejecutamos la formula de correlación y nos da una matriz de correlaciones.
# Out:
# array([[1.       , 0.9422735],
#        [0.9422735, 1.       ]])

# %%
np.corrcoef([df["ArrDelay"],df["DepDelay"],df["DepTime"]])
# Out:
# array([[1.        , 0.9422735 , 0.23241529],
#        [0.9422735 , 1.        , 0.25725889],
#        [0.23241529, 0.25725889, 1.        ]])

# %%
df.drop(inplace=True, columns = ["Year", "Cancelled", "Diverted", "Month"])
# Elimonar columnas que no son numéricas o variables dummy

# %%
df.corr()
# muestra matriz de correlaciones
# Out:
#                    DayofMonth  DayOfWeek   DepTime  CRSDepTime   ArrTime  \
# DayofMonth           1.000000  -0.118851 -0.001168    0.003749 -0.004445
# DayOfWeek           -0.118851   1.000000  0.031111    0.024400  0.021947
# DepTime             -0.001168   0.031111  1.000000    0.985504  0.796903
# CRSDepTime           0.003749   0.024400  0.985504    1.000000  0.795609
# ArrTime             -0.004445   0.021947  0.796903    0.795609  1.000000
# CRSArrTime          -0.001941   0.027785  0.852191    0.862782  0.887002
# FlightNum            0.072588  -0.039560  0.023409    0.023789  0.011193
# ActualElapsedTime    0.004568   0.015945 -0.069542   -0.074644  0.013706
# CRSElapsedTime      -0.006886   0.017744 -0.065937   -0.070060  0.016936
# AirTime              0.000893   0.014324 -0.065054   -0.069232  0.018445
# ArrDelay             0.027501   0.085299  0.232415    0.180684  0.076353
# DepDelay             0.007231   0.098220  0.257259    0.202200  0.091164
# ...

# %%
# corr = round(df.corr(),3)
corr=corr.round(2)
# redondear los valores de la matriz de correlaciones a 3 decimales
corr.style.background_gradient()
# aplica una gradiente a la matriz
# Out:
# <style  type="text/css" >
# #T_d2684_row0_col0,#T_d2684_row1_col1,#T_d2684_row2_col2,#T_d2684_row3_col3,#T_d2684_row4_col4,#T_d2684_row5_col5,#T_d2684_row6_col6,#T_d2684_row7_col7,#T_d2684_row8_col8,#T_d2684_row9_col9,#T_d2684_row10_col10,#T_d2684_row11_col11,#T_d2684_row12_col12,#T_d2684_row13_col13,#T_d2684_row14_col14,#T_d2684_row15_col15,#T_d2684_row16_col16,#T_d2684_row17_col17,#T_d2684_row18_col18,#T_d2684_row19_col19{
#             background-color:  #023858;
#             color:  #f1f1f1;
# ...

# %%
df = pd.DataFrame([(.21, .32), (.01, .67), (.66, .03), (.21, .18)],
                  columns=['dogs', 'cats'])
df
# Out:
#    dogs  cats
# 0  0.21  0.32
# 1  0.01  0.67
# 2  0.66  0.03
# 3  0.21  0.18

# %%
df.round(1)
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0      2008      1           3          4   2003.0        1955   2211.0
# 1      2008      1           3          4    754.0         735   1002.0
# 2      2008      1           3          4    628.0         620    804.0
# 3      2008      1           3          4    926.0         930   1054.0
# 4      2008      1           3          4   1829.0        1755   1959.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...
